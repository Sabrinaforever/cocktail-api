# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabrinaforever/cocktail-api/blob/master/202403261.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/airbnb_listing_2018.csv")

# %%
df_cancellation_policy=df[["cancellation_policy"]]
df_cancellation_policy.head()
# Out:
#            cancellation_policy
# 0                     flexible
# 1                     flexible
# 2  strict_14_with_grace_period
# 3  strict_14_with_grace_period
# 4                     flexible

# %%
df_cancellation_policy.shape
# Out:
# (1518, 1)

# %%
flexible=True
print(not flexible)
print(df_cancellation_policy)
# Out:
# False
#               cancellation_policy
# 0                        flexible
# 1                        flexible
# 2     strict_14_with_grace_period
# 3     strict_14_with_grace_period
# 4                        flexible
# ...                           ...
# 1513                     flexible
# 1514                     flexible
# 1515                     flexible
# 1516                     flexible
# 1517                     flexible
#
# [1518 rows x 1 columns]

# %%
df_flexible_cancel=df["cancellation_policy"]=="flexible"
print()
print(df_flexible_cancel)
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1513     True
# 1514     True
# 1515     True
# 1516     True
# 1517     True
# Name: cancellation_policy, Length: 1518, dtype: bool

# %%
df_flexible_cancel=df["cancellation_policy"]=="flexible"

print(df_flexible_cancel)

df.shape
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1513     True
# 1514     True
# 1515     True
# 1516     True
# 1517     True
# Name: cancellation_policy, Length: 1518, dtype: bool
# (1518, 24)

# %%
df.columns.values
# Out:
# array(['id', 'host_id', 'host_name', 'host_is_superhost', 'neighbourhood',
#        'city', 'zipcode', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'minimum_nights',
#        'maximum_nights', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable', 'cancellation_policy', 'reviews_per_month',
#        'price', 'extra_people', 'cleaning_fee'], dtype=object)

# %%
flexible_cancel=df[df_flexible_cancel]
flexible_cancel.shape
# Out:
# (533, 24)

# %%
df_two_neighbourhood=df[(df["property_type"]=="Apartment")&((df["neighbourhood"]=="Clifton")|(df["neighbourhood"]=="Horfield"))]
df_two_neighbourhood.shape
df_two_neighbourhood.head(50)
# Out:
#            id    host_id                 host_name host_is_superhost  \
# 1     2446524   12510269                   Namrata                 t
# 3     3545386    3949983             Jo And Andrew                 f
# 14   13537863   18195440                   Heather                 f
# 34   18952716   28932344                    Thomas                 f
# 40   19025857   83528919                   Suzanne                 f
# 44   19114465    3447377           Louisa And Mark                 t
# 50   19222171   12893378                   Natalie                 t
# 76   19569001   10260023                     Kevin                 f
# 86   19705234  138853785                 Catherine                 f
# 97   19862144   30750499                     Elena                 f
# 101  19964413  141546321                       Jey                 f
# 110  20111046   18583826                   Vanessa                 t
# 113  20153374  143390860                      Phil                 t
# ...

# %%
df["new_rating"]=df["review_scores_rating"]/20
df["new_rating"]
df["room_type"].count()
print(df)
# Out:
#             id    host_id       host_name host_is_superhost  \
# 0      1182074    6466360         Rebecca                 f
# 1      2446524   12510269         Namrata                 t
# 2      3015870   15369567            Mary                 f
# 3      3545386    3949983   Jo And Andrew                 f
# 4      8161251   39471780  Daniel  & Jess                 t
# ...        ...        ...             ...               ...
# 1513  43761494    7484271           Sammi                 f
# 1514  43775630   51686051         Michael                 f
# 1515  43794151   12773642            Lora                 f
# 1516  43795453  158978666          Air360                 f
# 1517  43826937  236481623         Mairead                 t
#
#                     neighbourhood             city  zipcode property_type  \
# 0     Avonmouth & Lawrence Weston  City of Bristol     BS11         House
# 1                         Clifton  City of Bristol  BS8 3LH     Apartment
# ...

# %%
import numpy as np

# %%
df["private_room"]=np.where(df["room_type"]=="Private room",1,0)
print(df)
# Out:
#             id    host_id       host_name host_is_superhost  \
# 0      1182074    6466360         Rebecca                 f
# 1      2446524   12510269         Namrata                 t
# 2      3015870   15369567            Mary                 f
# 3      3545386    3949983   Jo And Andrew                 f
# 4      8161251   39471780  Daniel  & Jess                 t
# ...        ...        ...             ...               ...
# 1513  43761494    7484271           Sammi                 f
# 1514  43775630   51686051         Michael                 f
# 1515  43794151   12773642            Lora                 f
# 1516  43795453  158978666          Air360                 f
# 1517  43826937  236481623         Mairead                 t
#
#                     neighbourhood             city  zipcode property_type  \
# 0     Avonmouth & Lawrence Weston  City of Bristol     BS11         House
# 1                         Clifton  City of Bristol  BS8 3LH     Apartment
# ...

# %%
df=df.rename(columns={"new_rating":"stars"})
print(df)
# Out:
#             id    host_id       host_name host_is_superhost  \
# 0      1182074    6466360         Rebecca                 f
# 1      2446524   12510269         Namrata                 t
# 2      3015870   15369567            Mary                 f
# 3      3545386    3949983   Jo And Andrew                 f
# 4      8161251   39471780  Daniel  & Jess                 t
# ...        ...        ...             ...               ...
# 1513  43761494    7484271           Sammi                 f
# 1514  43775630   51686051         Michael                 f
# 1515  43794151   12773642            Lora                 f
# 1516  43795453  158978666          Air360                 f
# 1517  43826937  236481623         Mairead                 t
#
#                     neighbourhood             city  zipcode property_type  \
# 0     Avonmouth & Lawrence Weston  City of Bristol     BS11         House
# 1                         Clifton  City of Bristol  BS8 3LH     Apartment
# ...

# %%
df_no_index12=df.drop(df.index[[1,2]])
df_less=df.drop("review_scores_rating",axis=1)
print(df_less)
# Out:
#             id    host_id       host_name host_is_superhost  \
# 0      1182074    6466360         Rebecca                 f
# 1      2446524   12510269         Namrata                 t
# 2      3015870   15369567            Mary                 f
# 3      3545386    3949983   Jo And Andrew                 f
# 4      8161251   39471780  Daniel  & Jess                 t
# ...        ...        ...             ...               ...
# 1513  43761494    7484271           Sammi                 f
# 1514  43775630   51686051         Michael                 f
# 1515  43794151   12773642            Lora                 f
# 1516  43795453  158978666          Air360                 f
# 1517  43826937  236481623         Mairead                 t
#
#                     neighbourhood             city  zipcode property_type  \
# 0     Avonmouth & Lawrence Weston  City of Bristol     BS11         House
# 1                         Clifton  City of Bristol  BS8 3LH     Apartment
# ...

# %%
df["apartment"]=np.where(df["property_type"]=="Apartment",1,0)
df.groupby(["apartment"]).sum()
# Out:
# <ipython-input-81-70ddb27a2070>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["apartment"]).sum()
#                     id       host_id  accommodates  bathrooms  bedrooms  \
# apartment
# 0          29729583242  105561179513          3245     1284.0      1547
# 1          17396671749   63681441553          1794      671.5       747
#
#              beds  minimum_nights  maximum_nights  number_of_reviews  \
# apartment
# 0          1904.0            2330          582856              19536
# 1           992.0            2007          370506              16818
#
#            review_scores_rating  reviews_per_month  price  extra_people  \
# apartment
# 0                       73881.0            1029.83  81876          6983
# ...

# %%
pivot_two_neighbourhood=pd.pivot_table(df_two_neighbourhood,index="host_is_superhost")
pivot_agg=pd.pivot_table(df,index=["stars"],values=["host_is_superhost"],aggfunc=[np.mean])
# Out:
# <ipython-input-91-6fae4e28b87a>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pivot_two_neighbourhood=pd.pivot_table(df_two_neighbourhood,index="host_is_superhost")
# <ipython-input-91-6fae4e28b87a>:2: FutureWarning: The operation <function mean at 0x7a6ca3f6f010> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pivot_agg=pd.pivot_table(df,index=["stars"],values=["host_is_superhost"],aggfunc=[np.mean])

# %%
df.groupby(["property_type"]).groups.keys()
# Out:
# dict_keys(['Apartment', 'Bed and breakfast', 'Boat', 'Boutique hotel', 'Bungalow', 'Cabin', 'Camper/RV', 'Condominium', 'Cottage', 'Guest suite', 'Guesthouse', 'Hostel', 'Hotel', 'House', 'Loft', 'Serviced apartment', 'Tiny house', 'Townhouse'])

# %%
df.replace(to_replace="Townhouse",value="House" )
# Out:
#             id    host_id       host_name host_is_superhost  \
# 0      1182074    6466360         Rebecca                 f
# 1      2446524   12510269         Namrata                 t
# 2      3015870   15369567            Mary                 f
# 3      3545386    3949983   Jo And Andrew                 f
# 4      8161251   39471780  Daniel  & Jess                 t
# ...        ...        ...             ...               ...
# 1513  43761494    7484271           Sammi                 f
# 1514  43775630   51686051         Michael                 f
# 1515  43794151   12773642            Lora                 f
# 1516  43795453  158978666          Air360                 f
# 1517  43826937  236481623         Mairead                 t
#
#                     neighbourhood             city  zipcode property_type  \
# 0     Avonmouth & Lawrence Weston  City of Bristol     BS11         House
# 1                         Clifton  City of Bristol  BS8 3LH     Apartment
# ...

# %%
df.to_csv("file_path_here.csv",index=False)

# %%
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['flexible']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
select_boo1=df["property_type"]=="House"
new_house=df[select_boo1]

# %%
select_boo2=df["property_type"]=="Apartment"
new_apartment=df[select_boo2]

# %%
series_house = new_house["review_scores_rating"]/20
series_apartment = new_apartment["review_scores_rating"]/20

# %%
plt.hist(series_house)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(series_house,color="yellow",label="House")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(series_apartment,color="red",label="Apartment", bins=30, alpha=0.3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(series_apartment, alpha=0.5)
plt.xlabel("Rating")
plt.ylabel("Number of Rating Scores")
plt.title("Distribution of review scores for apartments")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist([series_apartment,series_house], label=["apartment","house"])
plt.xlabel("Rating")
plt.ylabel("Number of Rating Scores")
plt.title("Distribution of review scores for apartments")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist([series_apartment,series_house], label=["apartment","house"])
plt.xlabel("Rating")
plt.ylabel("Number of Rating Scores")
plt.title("Distribution of review scores for apartments")
plt.legend(loc="best")
plt.xlim([3,5])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
